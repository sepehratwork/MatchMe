# %% [markdown]
# # Initialization

# %%
from main import Extractor
from database import save_domains_intents_into_db

# %%
extractor_en = Extractor(model_name="sentence-transformers/all-mpnet-base-v2", v_db="domain_intent_en")
extractor_fa = Extractor(model_name="heydariAI/persian-embeddings", v_db="domain_intent_fa")
# Out:
# 2025-02-28 02:52:29.575526: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-28 02:52:29.584416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740698549.594785  128881 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740698549.597777  128881 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-28 02:52:29.609122: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
embeddings_en = extractor_en.embeddings
embeddings_fa = extractor_fa.embeddings

# %% [markdown]
# # Saving Documents into Vectors for VectorDB

# %%
# !rm -r domain_intent_en
# !rm -r domain_intent_fa
# Out:
# /bin/bash: /home/sepehr/.conda/envs/sepehr/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/sepehr/.conda/envs/sepehr/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !mkdir domain_intent_en
# !mkdir domain_intent_fa
# Out:
# /bin/bash: /home/sepehr/.conda/envs/sepehr/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/sepehr/.conda/envs/sepehr/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
save_domains_intents_into_db(embeddings=embeddings_en, db_path="domain_intent_en", json_path="domain.json")
save_domains_intents_into_db(embeddings=embeddings_fa, db_path="domain_intent_fa", json_path="domain_persian.json")
# Out:
# Adding examples of domain Cancel and intent None with 61 examples
# Adding examples of domain T-shirts and intent None with 30 examples
# Adding examples of domain T-shirts and intent Buying with 30 examples
# Adding examples of domain T-shirts and intent Selling with 30 examples
# Adding examples of domain Polo shirts and intent None with 30 examples
# Adding examples of domain Polo shirts and intent Buying with 30 examples
# Adding examples of domain Polo shirts and intent Selling with 30 examples
# Adding examples of domain Blouses and intent None with 30 examples
# Adding examples of domain Blouses and intent Buying with 30 examples
# Adding examples of domain Blouses and intent Selling with 30 examples
# Adding examples of domain Dress shirts and intent None with 29 examples
# Adding examples of domain Dress shirts and intent Buying with 30 examples
# Adding examples of domain Dress shirts and intent Selling with 30 examples
# Adding examples of domain Tank tops and intent None with 29 examples
# Adding examples of domain Tank tops and intent Buying with 30 examples
# Adding examples of domain Tank tops and intent Selling with 29 examples
# Adding examples of domain Crop tops and intent None with 30 examples
# Adding examples of domain Crop tops and intent Buying with 30 examples
# Adding examples of domain Crop tops and intent Selling with 30 examples
# Adding examples of domain Sweatshirts and intent None with 29 examples
# Adding examples of domain Sweatshirts and intent Buying with 30 examples
# Adding examples of domain Sweatshirts and intent Selling with 29 examples
# Adding examples of domain Hoodies and intent None with 29 examples
# Adding examples of domain Hoodies and intent Buying with 29 examples
# Adding examples of domain Hoodies and intent Selling with 29 examples
# Adding examples of domain Sweaters and intent None with 28 examples
# Adding examples of domain Sweaters and intent Buying with 28 examples
# Adding examples of domain Sweaters and intent Selling with 27 examples
# Adding examples of domain Cardigans and intent None with 28 examples
# Adding examples of domain Cardigans and intent Buying with 28 examples
# Adding examples of domain Cardigans and intent Selling with 28 examples
# Adding examples of domain Pullovers and intent None with 28 examples
# Adding examples of domain Pullovers and intent Buying with 27 examples
# Adding examples of domain Pullovers and intent Selling with 28 examples
# Adding examples of domain Tunics and intent None with 27 examples
# Adding examples of domain Tunics and intent Buying with 27 examples
# Adding examples of domain Tunics and intent Selling with 26 examples
# Adding examples of domain Jeans and intent None with 28 examples
# Adding examples of domain Jeans and intent Buying with 27 examples
# Adding examples of domain Jeans and intent Selling with 26 examples
# Adding examples of domain Pants and intent None with 28 examples
# Adding examples of domain Pants and intent Buying with 27 examples
# Adding examples of domain Pants and intent Selling with 26 examples
# Adding examples of domain Chinos and intent None with 28 examples
# Adding examples of domain Chinos and intent Buying with 27 examples
# Adding examples of domain Chinos and intent Selling with 26 examples
# Adding examples of domain Trousers and intent None with 28 examples
# Adding examples of domain Trousers and intent Buying with 28 examples
# Adding examples of domain Trousers and intent Selling with 26 examples
# Adding examples of domain Leggings and intent None with 28 examples
# Adding examples of domain Leggings and intent Buying with 26 examples
# Adding examples of domain Leggings and intent Selling with 25 examples
# Adding examples of domain Joggers and intent None with 30 examples
# Adding examples of domain Joggers and intent Buying with 30 examples
# Adding examples of domain Joggers and intent Selling with 30 examples
# Adding examples of domain Shorts and intent None with 30 examples
# Adding examples of domain Shorts and intent Buying with 30 examples
# Adding examples of domain Shorts and intent Selling with 30 examples
# Adding examples of domain Skirts and intent None with 30 examples
# Adding examples of domain Skirts and intent Buying with 30 examples
# Adding examples of domain Skirts and intent Selling with 30 examples
# Adding examples of domain Culottes and intent None with 30 examples
# Adding examples of domain Culottes and intent Buying with 30 examples
# Adding examples of domain Culottes and intent Selling with 30 examples
# Adding examples of domain Casual dresses and intent None with 30 examples
# Adding examples of domain Casual dresses and intent Buying with 30 examples
# Adding examples of domain Casual dresses and intent Selling with 30 examples
# Adding examples of domain Formal dresses and intent None with 30 examples
# Adding examples of domain Formal dresses and intent Buying with 30 examples
# Adding examples of domain Formal dresses and intent Selling with 30 examples
# Adding examples of domain Maxi dresses and intent None with 30 examples
# Adding examples of domain Maxi dresses and intent Buying with 30 examples
# Adding examples of domain Maxi dresses and intent Selling with 30 examples
# Adding examples of domain Midi dresses and intent None with 30 examples
# Adding examples of domain Midi dresses and intent Buying with 30 examples
# Adding examples of domain Midi dresses and intent Selling with 30 examples
# Adding examples of domain Mini dresses and intent None with 30 examples
# Adding examples of domain Mini dresses and intent Buying with 30 examples
# Adding examples of domain Mini dresses and intent Selling with 30 examples
# Adding examples of domain Cocktail dresses and intent None with 30 examples
# Adding examples of domain Cocktail dresses and intent Buying with 30 examples
# Adding examples of domain Cocktail dresses and intent Selling with 30 examples
# Adding examples of domain Sundresses and intent None with 29 examples
# Adding examples of domain Sundresses and intent Buying with 28 examples
# Adding examples of domain Sundresses and intent Selling with 29 examples
# Adding examples of domain Sweater dresses and intent None with 29 examples
# Adding examples of domain Sweater dresses and intent Buying with 27 examples
# Adding examples of domain Sweater dresses and intent Selling with 27 examples
# Adding examples of domain Shift dresses and intent None with 27 examples
# Adding examples of domain Shift dresses and intent Buying with 29 examples
# Adding examples of domain Shift dresses and intent Selling with 28 examples
# Adding examples of domain Jackets and intent None with 28 examples
# Adding examples of domain Jackets and intent Buying with 28 examples
# Adding examples of domain Jackets and intent Selling with 28 examples
# Adding examples of domain Coats and intent None with 28 examples
# Adding examples of domain Coats and intent Buying with 28 examples
# Adding examples of domain Coats and intent Selling with 28 examples
# Adding examples of domain Blazers and intent None with 28 examples
# Adding examples of domain Blazers and intent Buying with 28 examples
# Adding examples of domain Blazers and intent Selling with 29 examples
# Adding examples of domain Parkas and intent None with 28 examples
# Adding examples of domain Parkas and intent Buying with 29 examples
# Adding examples of domain Parkas and intent Selling with 28 examples
# Adding examples of domain Trench coats and intent None with 27 examples
# Adding examples of domain Trench coats and intent Buying with 27 examples
# Adding examples of domain Trench coats and intent Selling with 28 examples

# %% [markdown]
# # Testing

# %%
extractor_fa.domain_intent("دوستم یه جفت جین میخواد")
# Out:
# /home/sepehr/Work/MatchMe/main.py:21: UserWarning: Relevance scores must be between 0 and 1, got [(Document(id='Cancel_None_58', metadata={'domain': 'Cancel', 'intent': 'None'}, page_content='Close this matter and cancel it.'), -0.05983215479397619)]
#   results = self.vector_store.similarity_search_with_relevance_scores(
